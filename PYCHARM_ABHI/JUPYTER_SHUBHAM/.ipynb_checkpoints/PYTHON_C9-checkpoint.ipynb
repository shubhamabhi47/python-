# %%
# wap to join the following sets set1=collection of alphabets upto E
# set2=collection  of natural numbers from 10 to 14
# set3 is a collection of name of 5 subjects
# set 4 is collection of the marks of those subjects

# %%
s1={'A','B','C','D','E'}
s2={10,11,12,13,14}
s3={"maths","english","chem","phy","bio"}
s4={12,45,65,43,54}
s5=s2.intersection(s4)
print(s5)
# Out:
# {12}

# %%
s1={'A','B','C','D','E'}
s2=(10,11,12,13,14)
s4=s1.union(s2)

print(s4)
# Out:
# {10, 11, 12, 13, 14, 'B', 'A', 'E', 'C', 'D'}

# %%
there are two sets of students eac is a colelcto n of 5 where the first set of students are from oop and onther set of astudenta are fro mpython find the set of the students who are ateending both the classes

# %%
s1={"yash","Himanshi","Shubham"}
s2={"Himanshi","yash"}
print(s1.difference(s2))
s1.difference_update(s2)
# print(s1)
# Out:
# {'Shubham'}
