# %%
#type of operator based on operand
#1=unary --> 1)unary plus 2)unary minus 3)unary not 4) unary bitwise operator
#2=binary --> 1) Arthimatic 2) Assigment 3) comparison 4)logical 5)bitwise 6)identity 7)membership

# %%
#floor value(//) and ceil value()
#floor value(//) and ceil value()

# %%
#wap to take any two var and show the operations on these ops
x=3
y=4
z=5.9999
a=x+y
b=x*y
c=x/y
d=x%y
e=x**y
f=(z//y)
print(a,b,c,d,e,f)
# Out:
# 7 12 0.75 3 81 1.0

# %%
x=[2,3]
y=[2,3]
y=x
print(x is y)
print(y is x)
print(x is y)
print(x == y)
# Out:
# True
# True
# True
# True
