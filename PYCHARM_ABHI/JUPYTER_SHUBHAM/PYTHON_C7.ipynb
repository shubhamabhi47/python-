# %%
#LIST (CHANGEABLE,ORDERED, ALLOW DUPLICATES), TUPLES , SET, DICTIONARY
list=[" "," "," "]
print(list)
# Out:
# [' ', ' ', ' ']

# %%
# type()
my_var = 42
print(type(my_var))  # Output: <class 'int'>

# thislist = list(())
# Out:
# <class 'int'>

# %%
#LIST
list =["a","b","c","d","e","f"]
print(list[:4])
print(list[0:4])
print(list[1:4])
print(list[-1:4])
print(list[-1:0])
print(list[-4:-1])
print(list[-4:-2])
print(list[-4:])
print(list[2:5])
# Out:
# ['a', 'b', 'c', 'd']
# ['a', 'b', 'c', 'd']
# ['b', 'c', 'd']
# []
# []
# ['c', 'd', 'e']
# ['c', 'd']
# ['c', 'd', 'e', 'f']
# ['c', 'd', 'e']

# %%
chng=["Lalu","Yadav","Anand","Thakur","Rohit"]
chng[2]=["Vipul"]
print(chng)
# Out:
# ['Lalu', 'Yadav', ['Vipul'], 'Thakur', 'Rohit']

# %%
fruit = ["Apple","Banana","Cherry"]
fruit[1:3] = ["Watermelon"]
print(fruit)
# Out:
# ['Apple', 'Watermelon']

# %%
fruit = ["Apple","Banana","Cherry"]
fruit[1:2] = ["Watermelon"]
print(fruit)
# Out:
# ['Apple', 'Watermelon', 'Cherry']

# %%
fruit = ["Apple","Banana","Cherry"]
fruit.append("Orange")
print(fruit)
# Out:
# ['Apple', 'Banana', 'Cherry', 'Orange']

# %%
fruit = ["Apple","Banana","Cherry"]
fruit.insert(1,"pomegranate")
print(fruit)
# Out:
# ['Apple', 'pomegranate', 'Banana', 'Cherry']

# %%
fruit1 = ["Apple","Banana","Cherry"]
fruit2 = ["Guava","Grapes","Pomegranate"]
fruit1.extend(fruit2)
print(fruit1)
# Out:
# ['Apple', 'Banana', 'Cherry', 'Guava', 'Grapes', 'Pomegranate']

# %%
#
lists = ["A","B","C"]
tuples = ("a","b","c")

# %%
#REMOVE()
fruit = ["Apple","Banana","Cherry"]
fruit.remove("Apple")
print(fruit)
# Out:
# ['Banana', 'Cherry']

# %%
#POP()
fruit = ["Apple","Banana","Cherry"]
fruit.pop(1)
print(fruit)
# Out:
# ['Apple', 'Cherry']

# %%
fruit = ["Apple","Banana","Cherry","Pomegranate"]
del fruit[2]
print(fruit)
# Out:
# ['Apple', 'Banana', 'Pomegranate']

# %%
fruit = ["Apple","Banana","Cherry"]
del fruit
# print(fruit)

# %%
fruit = ["Apple","Banana","Cherry"]
fruit.clear()
print(fruit)
# Out:
# []

# %%
# Three parameter to reverse string
str = "string"
str[:-1]
# str[::-1]
str[-1::-1]
# Out:
# 'gnirts'
