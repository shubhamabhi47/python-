# %%
#write a prgram to take one var with the value 10 and another var with val 5.6 show the result by adding them 
#then print only the integer part of the output

# %%
# wap to take string i am doing py show the outout of the string and position of 6th and 2 to 7 and 4th oonwards
str="i am doing"
str[6]
str[2:7]
str[4:0]
# Out:
# ''

# %%
str[]
# Out:
# 'd'

# %%
str[2:7]
# Out:
# 'am do'

# %%
str[4:0]
# Out:
# ''

# %%
str[4:]
# Out:
# ' doing'
