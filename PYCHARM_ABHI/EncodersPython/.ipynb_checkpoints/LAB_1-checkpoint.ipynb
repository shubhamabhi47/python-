# %%
print("abd")
print(123)
print("00000")
print(100011)
# print(00011) will give error due to octal num
print(0o01)
print(" ")
print()
print("Byte Code")
# Out:
# abd
# 123
# 00000
# 100011
# 1
#
#
# Byte Code

# %%
a=40
b=9.23947634873734628735289358293
s="Gendu"
x=2
x=x+2
print(type(a))
print(type(b))
print(type(s))
print("X is:",x)
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# X is: 4

# %%
a=4
b=5
print(a+b)
print(a*b)
print(a**b)
print(a-b)
print(a//b)
print(a/b)
# Out:
# 9
# 20
# 1024
# -1
# 0
# 0.8

# %%
a="24"
b=2
# int(a) error 
# b=int(a)+2
# c=float(a)+2
# c=(a)+2
print(b,c)
print(int(a)+b)
# Out:
# 2 26.0
# 26

# %%
a=int(input("Enter any num:"))
b=a+2
print("sum is:",b)
# Out:
# Enter any num: 1
# sum is: 3

# %%
# wap to take hours rate and compute gross pay  //gross pay = h*rate
hour=float(input("Enter time in hours:"))
rate=float(input("Enter the rate:"))
print("Gross pay is: ",hour*rate)
# Out:
# Enter time in hours: 1.2
# Enter the rate: 1.5
# Gross pay is:  1.7999999999999998

# %%
a=9
if(a<10):
    print("less")
# else:
    print("Done")
# Out:
# less
# Done

# %%
# one way condition and two way condition
a=10
if(a>=10):
    print("High")
else:
    print("Low")
print("Program Ended!")
# Out:
# High
# Program Ended!

# %%
a=29
if(a==20):
    print("Perfect")
elif(a > 20):
    print("High")
else:
    print("Low")
# Out:
# High

# %%
# wap to entr hours and rate and calculate the pay condition 1.5 times the hourly rate for working more  than 40 hours
h= int(input("Enter time in hours:"))
r= int(input("Enter rate:"))
if(h<=40):
    print("Gross pay is:",h*r)
elif(h>40):
    print("Gross pay is :",(40*r)+1.5*(h-40)*r)
# Out:
# Enter time in hours: 45
# Enter rate: 10
# Gross pay is : 475.0

# %%
a=10
while(a<15):
 a=a+1
 print("Lalu")
else:
 print("fadu")
# Out:
# Lalu
# Lalu
# Lalu
# Lalu
# Lalu
# fadu

# %%
# for i in range(0,6):
for i in range(6):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
a=25
b=0
while(a<50):
    a=a+1
    b=b+1
    # print(a)
print(b)
# Out:
# 25

# %%
for i in "hhaoihhhfjaifoh":
    if(i=="h"):
        continue
    print(i)
# Out:
# a
# o
# i
# f
# j
# a
# i
# f
# o

# %%
for i in "aabac":
  if(i=="a"):
    continue
  print(i)
# Out:
# b
# c
